# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
DQN_lane = pd.read_csv('##IDQN_metrics_lane.csv')
MP_lane = pd.read_csv('Max_pressure_metrics_lane.csv')

DQN_veh = pd.read_csv('##IDQN_metrics_veh.csv')
MP_veh = pd.read_csv('Max_pressure_metrics_veh.csv')

DQN_lane.head()
# Out:
#    step laneID  WaitingTime  CO2
# 0    10    4_2          0.0  0.0
# 1    10    5_1          0.0  0.0
# 2    10   -7_1          0.0  0.0
# 3    10    7_0          0.0  0.0
# 4    10    3_2          0.0  0.0

# %%
DQN_lane_step = DQN_lane.groupby('step').agg({'WaitingTime':'mean','CO2':'mean'}).reset_index()
MP_lane_step = MP_lane.groupby('step').agg({'WaitingTime':'mean','CO2':'mean'}).reset_index()

DQN_vehicle_step = DQN_veh.groupby('step').agg({'TimeLoss':'mean','AccumulatedWaitingTime':'mean'}).reset_index()
MP_vehicle_step = MP_veh.groupby('step').agg({'TimeLoss':'mean','AccumulatedWaitingTime':'mean'}).reset_index()

DQN_lane_step.head()
# Out:
#    step  WaitingTime          CO2
# 0    10     0.000000   303.724875
# 1    20     0.033333   516.234724
# 2    30     0.133333   698.719039
# 3    40     0.266667   779.652450
# 4    50     0.966667  1057.223788

# %%
fig = plt.figure()

plt.plot(DQN_lane_step['step'],DQN_lane_step['WaitingTime'], label = 'IDQN')
plt.plot(MP_lane_step['step'],MP_lane_step['WaitingTime'], label = 'MP')

plt.title("Each lane Accumulat Waiting Time")
plt.ylabel("waiting time")
plt.xlabel("time step")

fig.legend()

# %%
fig = plt.figure()

plt.plot(DQN_lane_step['step'],DQN_lane_step['CO2'], label = 'IDQN')
plt.plot(MP_lane_step['step'],MP_lane_step['CO2'], label = 'MP')

plt.title("Each lane Accumulat Waiting Time")
plt.ylabel("waiting time")
plt.xlabel("time step")

fig.legend()

# %%
fig = plt.figure()
plt.plot(DQN_vehicle_step['step'],DQN_vehicle_step['TimeLoss'], label = 'IDQN')
plt.plot(MP_vehicle_step['step'],MP_vehicle_step['TimeLoss'], label = 'MP')

plt.title("Each vehicle time loss")
plt.ylabel("time loss")
plt.xlabel("time step")

fig.legend()

# %%
fig = plt.figure()
plt.plot(DQN_vehicle_step['step'],DQN_vehicle_step['AccumulatedWaitingTime'], label = 'IDQN')
plt.plot(MP_vehicle_step['step'],MP_vehicle_step['AccumulatedWaitingTime'], label = 'MP')

plt.title("Each vehicle accumulated waiting time")
plt.ylabel("accumulated waiting time")
plt.xlabel("time step")

fig.legend()

# %%
vehicle = pd.read_csv('AAA_metrics_veh.csv')
vehicle.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 vehicle = pd.read_csv('AAA_metrics_veh.csv')
#       2 vehicle.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
vehicle_step = vehicle.groupby('step').agg({'TimeLoss':'mean','AccumulatedWaitingTime':'mean'}).reset_index()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(vehicle_step['step'],vehicle_step['TimeLoss'],'-', label = 'TimeLoss')

ax2 = ax.twinx()
ax2.plot(vehicle_step['step'],vehicle_step['AccumulatedWaitingTime'],'r', label = 'AccumulatedWaitingTime')
fig.legend()

ax.set_xlabel('Time Step')
ax.set_ylabel('Time Loss')
ax2.set_ylabel('AccumulatedWaitingTime')
# Out:
# Text(0, 0.5, 'AccumulatedWaitingTime')

# %%
plt.plot(vehicle_step['step'],vehicle_step['TimeLoss'])

# %%
plt.plot(vehicle_step['step'],vehicle_step['TimeLoss'])
